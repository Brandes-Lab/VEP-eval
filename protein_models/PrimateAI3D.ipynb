# %% [markdown]
# Ensure you have a benchmark, e.g. ./benchmark/ClinVarBenchmark_PB_202504.csv <br>
# Also download precomputed PrimateAI3D scores from https://primateai3d.basespace.illumina.com/

# %%
import sys
# !{sys.executable} -m pip install mygene
# Out:
# Requirement already satisfied: mygene in c:\users\lxsbx\anaconda3\lib\site-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\users\lxsbx\anaconda3\lib\site-packages (from mygene) (0.5.0)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\lxsbx\anaconda3\lib\site-packages (from biothings-client>=0.2.6->mygene) (0.28.1)
# Requirement already satisfied: anyio in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (4.7.0)
# Requirement already satisfied: certifi in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.0.9)
# Requirement already satisfied: idna in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\lxsbx\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lxsbx\anaconda3\lib\site-packages (from anyio->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.3.0)

# %%
import numpy as np
import pandas as pd
import mygene
from tqdm import tqdm

# ============================================================
# Config
# ============================================================
current_score_path = "all_scores_am.csv"
output_pai_score_path = "all_scores_pai.csv"
pai_path = "PrimateAI-3D.hg38.txt"

# ============================================================
# 1. Load benchmark/current score table
# ============================================================
benchmark_df = pd.read_csv(current_score_path, dtype={"#CHROM": str}).copy()
benchmark_df = benchmark_df.drop(columns=["pai_score"], errors="ignore")

benchmark_df["protein_variant"] = (
    benchmark_df["ClinVarName_AAREF"].astype(str) +
    benchmark_df["ClinVarName_AAPOS"].astype("Int64").astype(str) +
    benchmark_df["ClinVarName_AAALT"].astype(str)
)

print(f"Loaded benchmark rows: {len(benchmark_df)}")

# ============================================================
# 2. Load PrimateAI-3D ONCE
# ============================================================
pai_scores = pd.read_csv(pai_path, sep="\t").rename(columns={
    "chr": "#CHROM",
    "pos": "POS",
    "non_flipped_ref": "REF",
    "non_flipped_alt": "ALT",
    "score_PAI3D": "pai_score",
    "gene_name": "enst_id",
    "change_position_1based": "position",
    "ref_aa": "ref",
    "alt_aa": "alt",
})

pai_scores["#CHROM"] = pai_scores["#CHROM"].astype(str).str.replace("chr", "", regex=False)

pai_scores["enst_id"] = pai_scores["enst_id"].astype(str).str.replace(r"\.\d+$", "", regex=True)

pai_scores["protein_variant"] = (
    pai_scores["ref"].astype(str) +
    pai_scores["position"].astype("Int64").astype(str) +
    pai_scores["alt"].astype(str)
)

print("PrimateAI-3D columns:")
print(pai_scores.columns.tolist())

# ============================================================
# 3. Direct genomic-key merge table for normal variants
# ============================================================
merge_cols = ["#CHROM", "POS", "REF", "ALT", "protein_variant"]

required_merge_cols = merge_cols + ["pai_score"]
missing = [c for c in required_merge_cols if c not in pai_scores.columns]
if missing:
    raise ValueError(f"Missing required columns in PrimateAI-3D file: {missing}")

pai_var = pai_scores[merge_cols + ["pai_score"]].copy()

# Drop exact duplicates first
pai_var = pai_var.drop_duplicates()

# Identify inconsistent duplicate keys
dupes = pai_var[pai_var.duplicated(subset=merge_cols, keep=False)]

def inconsistent(group):
    return group["pai_score"].nunique(dropna=False) > 1

if not dupes.empty:
    bad_keys = (
        dupes.groupby(merge_cols, group_keys=False)
        .filter(inconsistent)[merge_cols]
        .drop_duplicates()
    )
else:
    bad_keys = pd.DataFrame(columns=merge_cols)

if not bad_keys.empty:
    print(f"❌ Found {len(bad_keys)} inconsistent PrimateAI keys. Setting pai_score = NaN")
    bad_key_set = set(map(tuple, bad_keys[merge_cols].to_numpy()))
    row_keys = list(map(tuple, pai_var[merge_cols].to_numpy()))
    mask = pd.Series(row_keys).isin(bad_key_set).to_numpy()
    pai_var.loc[mask, "pai_score"] = np.nan
else:
    print("✅ No inconsistent pai_scores")

# Ensure each genomic key maps to <= 1 pai_score
pai_var = pai_var.drop_duplicates(subset=merge_cols, keep="first")

# ============================================================
# 4. Merge normal genomic-key pai_score into benchmark
# ============================================================
before_len = len(benchmark_df)

benchmark_df = pd.merge(
    benchmark_df,
    pai_var,
    on=merge_cols,
    how="left"
)

after_len = len(benchmark_df)
print(f"benchmark len before merge = {before_len}")
print(f"benchmark len after merge  = {after_len}")

if before_len != after_len:
    print("⚠️ Row count changed after merge. Check duplicate keys in source data.")

# ============================================================
# 5. Map RefSeq -> ENST for stop-gain handling only
# ============================================================
mg = mygene.MyGeneInfo()
refseq_ids = benchmark_df["ClinVarName_refseq_ids"].dropna().unique().tolist()

results = mg.querymany(
    refseq_ids,
    scopes="refseq",
    fields="ensembl.transcript",
    species="human",
    as_dataframe=False
)

refseq_to_enst = {}
for res in results:
    refseq = res.get("query")
    enst = None

    if "ensembl" in res:
        ensembl_val = res["ensembl"]

        if isinstance(ensembl_val, dict):
            enst = ensembl_val.get("transcript")

        elif isinstance(ensembl_val, list):
            transcripts = []
            for item in ensembl_val:
                if isinstance(item, dict):
                    tr = item.get("transcript")
                    if isinstance(tr, list):
                        transcripts.extend(tr)
                    elif tr is not None:
                        transcripts.append(tr)
            enst = transcripts if transcripts else None

    refseq_to_enst[refseq] = enst

benchmark_df["enst_id"] = benchmark_df["ClinVarName_refseq_ids"].map(refseq_to_enst)

def strip_enst_version(x):
    if isinstance(x, list):
        return [str(v).split(".")[0] for v in x]
    elif pd.isna(x):
        return x
    else:
        return str(x).split(".")[0]

benchmark_df["enst_id"] = benchmark_df["enst_id"].apply(strip_enst_version)

print(f"len of enst dict = {len(refseq_to_enst)}")

# ============================================================
# 6. Prepare transcript/protein-position table for stop-gain logic
# ============================================================
stop_support_cols = ["enst_id", "position", "ref", "alt", "pai_score"]
existing_stop_cols = [c for c in stop_support_cols if c in pai_scores.columns]

pai_stop = pai_scores[existing_stop_cols].copy()
pai_stop = pai_stop.dropna(subset=["enst_id", "position"])

pai_stop["position"] = pd.to_numeric(pai_stop["position"], errors="coerce")
pai_stop = pai_stop.dropna(subset=["position"])
pai_stop["position"] = pai_stop["position"].astype(int)

# Optional but recommended: normalize ENST version suffix
pai_stop["enst_id"] = pai_stop["enst_id"].astype(str).str.replace(r"\.\d+$", "", regex=True)

# Group by transcript first, then deduplicate within each transcript
pai_dict = {enst: subdf.copy() for enst, subdf in pai_stop.groupby("enst_id")}

for enst in list(pai_dict.keys()):
    df = pai_dict[enst].drop_duplicates().copy()

    sub_cols = ["position", "ref", "alt"]
    dupes2 = df[df.duplicated(subset=sub_cols, keep=False)]

    if not dupes2.empty:
        bad_subkeys = (
            dupes2.groupby(sub_cols, group_keys=False)
            .filter(lambda g: g["pai_score"].nunique(dropna=False) > 1)[sub_cols]
            .drop_duplicates()
        )
    else:
        bad_subkeys = pd.DataFrame(columns=sub_cols)

    if not bad_subkeys.empty:
        bad_subkey_set = set(map(tuple, bad_subkeys[sub_cols].to_numpy()))
        sub_row_keys = list(map(tuple, df[sub_cols].to_numpy()))
        mask2 = pd.Series(sub_row_keys).isin(bad_subkey_set).to_numpy()
        df.loc[mask2, "pai_score"] = np.nan

    df = df.drop_duplicates(subset=sub_cols, keep="first")
    pai_dict[enst] = df

# ============================================================
# 7. Fill stop-gain variants using downstream worst-case score
# ============================================================
stop_gain_mask = benchmark_df["ClinVarName_AAALT"].astype(str) == "*"
stop_indices = benchmark_df.index[stop_gain_mask]

counter = 0

for idx in tqdm(stop_indices, desc="Processing stop-gains"):
    row = benchmark_df.loc[idx]
    ensts = row["enst_id"]
    stop_pos = row["ClinVarName_AAPOS"]

    if pd.isna(stop_pos):
        continue

    stop_pos = int(stop_pos)

    if ensts is None or (isinstance(ensts, float) and pd.isna(ensts)):
        continue

    if not isinstance(ensts, list):
        ensts = [ensts]

    worst_scores = []
    for enst in ensts:
        if enst not in pai_dict:
            continue

        subdf = pai_dict[enst]
        after = subdf[subdf["position"] >= stop_pos]

        if after.empty:
            continue

        score = after["pai_score"].max()
        if pd.notna(score):
            worst_scores.append(score)

    if worst_scores:
        benchmark_df.at[idx, "pai_score"] = max(worst_scores)
        counter += 1

print(f"✅ Total stop_gain rows updated = {counter}")

# ============================================================
# Final column cleanup & ordering
# ============================================================

# Drop transcript/helper columns from final output
benchmark_df = benchmark_df.drop(
    columns=["enst_id", "uniprot_id", "protein_variant"],
    errors="ignore"
)

# Reorder columns: put pai_score after (#CHROM, POS, ID)
cols = list(benchmark_df.columns)

anchor_cols = ["#CHROM", "POS", "ID"]
anchor_present = [c for c in anchor_cols if c in cols]

if "pai_score" in cols and anchor_present:
    cols.remove("pai_score")
    last_anchor_idx = max(cols.index(c) for c in anchor_present)
    cols.insert(last_anchor_idx + 1, "pai_score")
    benchmark_df = benchmark_df[cols]
else:
    print("⚠️ Could not reorder pai_score (missing columns?)")

# ============================================================
# 8. Save
# ============================================================
print(f"final benchmark len = {len(benchmark_df)}")
benchmark_df.to_csv(output_pai_score_path, index=False)
print("primateai3d_merge_stop_gain_combined.py done ✅")
# Out:
# Loaded benchmark rows: 242132
# PrimateAI-3D columns:
# ['#CHROM', 'POS', 'REF', 'ALT', 'enst_id', 'position', 'ref', 'alt', 'pai_score', 'percentile_PAI3D', 'refseq', 'prediction', 'protein_variant']
# ✅ No inconsistent pai_scores
# benchmark len before merge = 242132
# benchmark len after merge  = 242132
# 1 input query terms found no hit:	['NM_032374.4']
# len of enst dict = 11375
# Processing stop-gains: 100%|███████████████████████████████████████████████████| 42000/42000 [00:19<00:00, 2136.94it/s]
# ✅ Total stop_gain rows updated = 40970
# final benchmark len = 242132
# primateai3d_merge_stop_gain_combined.py done ✅

# %%
from sklearn.metrics import roc_auc_score
import pandas as pd

scores = [
    "pai_score",
    "am_score",
    "ESM1b_score",
    "ESM1v-1_score",
    "ESM2_score"
]

for s in scores:
    sub = benchmark_df[["ClinVar_label", s]].dropna()

    if sub["ClinVar_label"].nunique() < 2:
        print(f"{s}: skipped (only one class)")
        continue

    auc = roc_auc_score(sub["ClinVar_label"], sub[s])
    print(f"{s}: AUROC = {auc:.4f}")
# Out:
# pai_score: AUROC = 0.9847
# am_score: AUROC = 0.9891
# ESM1b_score: AUROC = 0.0232
# ESM1v-1_score: AUROC = 0.0343
# ESM2_score: AUROC = 0.0323

# %%
group_cols = [c for c in benchmark_df.columns if c.startswith("group:")]

results = []

for grp in group_cols:

    df_grp = benchmark_df[benchmark_df[grp] == 1]

    if len(df_grp) < 20:
        continue

    for s in scores:

        sub = df_grp[["ClinVar_label", s]].dropna()

        if len(sub) < 20:
            continue

        if sub["ClinVar_label"].nunique() < 2:
            continue

        auc = roc_auc_score(
            sub["ClinVar_label"],
            sub[s]
        )

        results.append({
            "group": grp,
            "score": s,
            "auroc": auc,
            "n": len(sub)
        })

auroc_df = pd.DataFrame(results)

# %%
pivot = auroc_df.pivot(
    index="group",
    columns="score",
    values="auroc"
)

print(pivot)
# Out:
# score                                   ESM1b_score  ESM1v-1_score  \
# group
# group: +                                   0.023532       0.037083
# group: -                                   0.022941       0.031666
# group: coding                              0.023244       0.034290
# group: missense                            0.067969       0.104224
# group: missense + 3'UTR                    0.028904       0.065837
# group: missense + intron (non-splice)      0.072802       0.126145
# group: start loss                          0.317532       0.367677
# group: stop gain                           0.222695       0.355115
# group: stop gain + intron (non-splice)     0.378446       0.626566
#
# score                                   ESM2_score  am_score  pai_score
# group
# group: +                                  0.032090  0.989317   0.984769
# group: -                                  0.032520  0.989010   0.984526
# group: coding                             0.032334  0.989130   0.984657
# group: missense                           0.106140  0.966127   0.952009
# group: missense + 3'UTR                   0.108792  0.939167   0.933333
# group: missense + intron (non-splice)     0.150813  0.955013   0.935955
# group: start loss                         0.291919       NaN        NaN
# group: stop gain                          0.326224  0.844355   0.797766
# group: stop gain + intron (non-splice)    0.195489  0.856725   0.748677
