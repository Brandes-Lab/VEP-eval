# %% [markdown]
# Ensure you have a benchmark, e.g. ./benchmark/ClinVarBenchmark_PB_202504.csv <br>
# Also check if the link below is still valid for precomputed AlphaMissense scores <br>
# https://zenodo.org/records/10813168/files/AlphaMissense_hg38.tsv.gz

# %%
import sys
# !{sys.executable} -m pip install mygene
# Out:
# Requirement already satisfied: mygene in c:\users\lxsbx\anaconda3\lib\site-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\users\lxsbx\anaconda3\lib\site-packages (from mygene) (0.5.0)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\lxsbx\anaconda3\lib\site-packages (from biothings-client>=0.2.6->mygene) (0.28.1)
# Requirement already satisfied: anyio in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (4.7.0)
# Requirement already satisfied: certifi in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.0.9)
# Requirement already satisfied: idna in c:\users\lxsbx\anaconda3\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\lxsbx\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lxsbx\anaconda3\lib\site-packages (from anyio->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.3.0)

# %%
from tqdm import tqdm
import requests
from pathlib import Path
import gzip
import shutil
import os

am_url = "https://zenodo.org/records/10813168/files/AlphaMissense_hg38.tsv.gz"
am_gz = "AlphaMissense_hg38.tsv.gz"
am_path = "AlphaMissense_hg38.tsv"

def download_resume(url, filename):
    temp_size = 0
    headers = {}

    if Path(filename).exists():
        temp_size = Path(filename).stat().st_size
        headers["Range"] = f"bytes={temp_size}-"

    with requests.get(url, stream=True, headers=headers) as r:
        total_size = int(r.headers.get("content-length", 0)) + temp_size

        mode = "ab" if temp_size > 0 else "wb"

        with open(filename, mode) as f, tqdm(
            total=total_size,
            initial=temp_size,
            unit="B",
            unit_scale=True,
            desc="Downloading"
        ) as bar:
            for chunk in r.iter_content(chunk_size=1024*1024):
                if chunk:
                    f.write(chunk)
                    bar.update(len(chunk))


if Path(am_path).exists():
    print("AlphaMissense_hg38.tsv exists, skip downloading")

else:
    print("Downloading AlphaMissense_hg38.tsv.gz ...")
    download_resume(am_url, am_gz)

    print("Unzipping...")
    with gzip.open(am_gz, "rb") as f_in, open(am_path, "wb") as f_out:
        shutil.copyfileobj(f_in, f_out)

    Path(am_gz).unlink()

print("✅ Done")
# Out:
# AlphaMissense_hg38.tsv exists, skip downloading
# ✅ Done

# %%
import math
import re
import numpy as np
import pandas as pd
import mygene
from tqdm import tqdm

# ============================================================
# Config
# ============================================================
current_score_path = "benchmark_scores.csv"
am_path = "AlphaMissense_hg38.tsv"
output_am_score_path = "all_scores_am.csv"
chunksize = 500_000

# ============================================================
# 1. Load benchmark/current score table
# ============================================================
benchmark_df = pd.read_csv(current_score_path, dtype = {0: str}).copy()
benchmark_df = benchmark_df.drop(columns=["am_score"], errors="ignore")

# ============================================================
# 2. Map NM_id -> UniProt ID (using MyGene)
# ============================================================
def map_nm_to_uniprot(nm_ids):
    """Map RefSeq NM IDs to UniProt IDs via MyGene."""
    mg = mygene.MyGeneInfo()
    results = mg.querymany(
        nm_ids,
        scopes="refseq",
        fields="uniprot",
        species="human",
        as_dataframe=False
    )

    nm_to_uniprot = {}
    for res in results:
        refseq = res.get("query")
        uniprot = res.get("uniprot", {})
        uniprot_id = None

        if isinstance(uniprot, dict):
            ids = uniprot.get("Swiss-Prot") or uniprot.get("TrEMBL")
            uniprot_id = ids[0] if isinstance(ids, list) else ids
        elif isinstance(uniprot, list):
            uniprot_id = uniprot[0] if uniprot else None
        else:
            uniprot_id = uniprot

        nm_to_uniprot[refseq] = uniprot_id

    return nm_to_uniprot


if "uniprot_id" not in benchmark_df.columns:
    nm_ids = benchmark_df["ClinVarName_refseq_ids"].dropna().unique().tolist()
    nm_to_uniprot = map_nm_to_uniprot(nm_ids)
    benchmark_df["uniprot_id"] = benchmark_df["ClinVarName_refseq_ids"].map(nm_to_uniprot)

benchmark_df["protein_variant"] = (
    benchmark_df["ClinVarName_AAREF"].astype(str) +
    benchmark_df["ClinVarName_AAPOS"].astype("Int64").astype(str) +
    benchmark_df["ClinVarName_AAALT"].astype(str)
)

needed_uniprots = set(benchmark_df["uniprot_id"].dropna())
print(f"✅ Finished mapping: {len(needed_uniprots)} UniProt IDs found.")

# ============================================================
# 3. Helper for parsing protein_variant
# ============================================================
AA_VOCAB = [
    "K","R","H","E","D","N","Q","T","S","C",
    "G","A","V","L","I","M","P","Y","F","W"
]

def parse_mut(protein_variant):
    """
    Parse protein variant like 'A123T' or 'W50*'.
    Returns (ref, pos, alt).
    """
    match = re.match(r"([A-Z])(\d+)([A-Z*])", str(protein_variant))
    if match:
        ref, pos, alt = match.groups()
        return ref, int(pos), alt
    return None, None, None

# ============================================================
# 4. Read AlphaMissense ONCE in chunks
#    Collect:
#    (a) direct-merge rows for ordinary variants
#    (b) per-protein rows for stop_gain handling
# ============================================================
merge_cols = ["#CHROM", "POS", "REF", "ALT"] + ["uniprot_id", "protein_variant"]

am_var_parts = []          # for direct merge
protein_variants = {}      # for stop_gain logic

with open(am_path) as f:
    total_lines = sum(1 for _ in f)

# subtract the 3 skipped header lines if desired
data_lines = max(total_lines - 3, 0)
n_chunks = math.ceil(data_lines / chunksize)

for chunk in tqdm(
    pd.read_csv(am_path, sep="\t", skiprows=3, chunksize=chunksize),
    total=n_chunks,
    desc="Reading AlphaMissense"
):
    chunk = chunk.rename(columns={"am_pathogenicity": "am_score"})

    if "uniprot_id" not in chunk.columns:
        continue

    # normalize chrom
    chunk["#CHROM"] = chunk["#CHROM"].astype(str).str.replace("chr", "", regex=False)

    # keep only proteins we care about
    chunk = chunk[chunk["uniprot_id"].isin(needed_uniprots)].copy()
    if chunk.empty:
        continue

    # ---------- (a) direct merge rows ----------
    # Only if these columns exist
    if set(merge_cols).issubset(chunk.columns):
        am_var_parts.append(chunk.loc[:, merge_cols + ["am_score"]].copy())

    # ---------- (b) stop_gain support ----------
    if "protein_variant" in chunk.columns:
        parsed = chunk["protein_variant"].apply(parse_mut)
        chunk[["ref", "pos", "alt"]] = pd.DataFrame(parsed.tolist(), index=chunk.index)

        keep_cols = ["uniprot_id", "ref", "pos", "alt", "am_score"]
        stop_df = chunk.loc[:, keep_cols].dropna(subset=["pos"]).copy()
        stop_df["pos"] = stop_df["pos"].astype(int)

        for uni, subdf in stop_df.groupby("uniprot_id"):
            if uni not in protein_variants:
                protein_variants[uni] = subdf.copy()
            else:
                protein_variants[uni] = pd.concat(
                    [protein_variants[uni], subdf],
                    ignore_index=True
                )

print(f"✅ Collected variants for {len(protein_variants)} proteins.")

# ============================================================
# 5. Build deduplicated direct-merge AlphaMissense table
# ============================================================
if am_var_parts:
    am_var = pd.concat(am_var_parts, ignore_index=True)
else:
    am_var = pd.DataFrame(columns=merge_cols + ["am_score"])

# Drop exact duplicates first
am_var = am_var.drop_duplicates()

# Find inconsistent duplicate keys
dupes = am_var[am_var.duplicated(subset=merge_cols, keep=False)]

def inconsistent(group):
    return group["am_score"].nunique(dropna=False) > 1

if not dupes.empty:
    bad_keys = (
        dupes.groupby(merge_cols, group_keys=False)
        .filter(inconsistent)[merge_cols]
        .drop_duplicates()
    )
else:
    bad_keys = pd.DataFrame(columns=merge_cols)

if not bad_keys.empty:
    print(f"❌ Found {len(bad_keys)} inconsistent keys. Setting am_score=NaN")
    bad_key_set = set(map(tuple, bad_keys[merge_cols].to_numpy()))
    row_keys = list(map(tuple, am_var[merge_cols].to_numpy()))
    mask = pd.Series(row_keys).isin(bad_key_set).to_numpy()
    am_var.loc[mask, "am_score"] = np.nan
else:
    print("✅ No inconsistent am_scores")

# After this, each key maps to <=1 am_score
am_var = am_var.drop_duplicates(subset=merge_cols, keep="first")

# ============================================================
# 6. Merge ordinary AlphaMissense scores
# ============================================================
before_len = len(benchmark_df)

benchmark_df = pd.merge(
    benchmark_df,
    am_var,
    on=merge_cols,
    how="left"
)

after_len = len(benchmark_df)
print(f"benchmark len before = {before_len}")
print(f"benchmark len after  = {after_len}")

# ============================================================
# 7. Deduplicate per-protein variants for stop_gain logic
# ============================================================
for uni in list(protein_variants.keys()):
    df = protein_variants[uni].drop_duplicates().copy()

    # If same (ref,pos,alt) appears with conflicting am_score, set to NaN
    sub_cols = ["ref", "pos", "alt"]
    dupes2 = df[df.duplicated(subset=sub_cols, keep=False)]

    if not dupes2.empty:
        bad_subkeys = (
            dupes2.groupby(sub_cols, group_keys=False)
            .filter(lambda g: g["am_score"].nunique(dropna=False) > 1)[sub_cols]
            .drop_duplicates()
        )
    else:
        bad_subkeys = pd.DataFrame(columns=sub_cols)
        
    if not bad_subkeys.empty:
        bad_subkey_set = set(map(tuple, bad_subkeys[sub_cols].to_numpy()))
        sub_row_keys = list(map(tuple, df[sub_cols].to_numpy()))
        mask2 = pd.Series(sub_row_keys).isin(bad_subkey_set).to_numpy()
        df.loc[mask2, "am_score"] = np.nan

    df = df.drop_duplicates(subset=sub_cols, keep="first")
    protein_variants[uni] = df

# ============================================================
# 8. Fill stop_gain AlphaMissense scores
# ============================================================
stop_mask = benchmark_df["ClinVarName_AAALT"].astype(str) == "*"
stop_indices = benchmark_df.index[stop_mask]

counter = 0
log = {}

for idx in tqdm(stop_indices, desc="Processing stop_gains"):
    row = benchmark_df.loc[idx]
    uni = row["uniprot_id"]
    stop_pos = row["ClinVarName_AAPOS"]

    if pd.isna(uni) or pd.isna(stop_pos):
        continue

    stop_pos = int(stop_pos)

    if uni not in protein_variants:
        continue

    pv = protein_variants[uni]
    after = pv[pv["pos"] >= stop_pos]

    if after.empty:
        continue

    # optional coverage check
    full_coverage = True
    for p in sorted(after["pos"].dropna().unique()):
        subdf = after.loc[after["pos"] == p]
        missing_aas = set(AA_VOCAB) - set(subdf["alt"].dropna())
        if missing_aas:
            wt_ref = subdf["ref"].iloc[0] if not subdf.empty else "?"
            log[uni] = f"{wt_ref}{p}{''.join(sorted(missing_aas))}"
            full_coverage = False
            break

    # worst-case score
    worst_score = after["am_score"].max()
    benchmark_df.at[idx, "am_score"] = worst_score
    counter += 1

print(f"✅ Number of stop_gain am_scores updated: {counter}")
print(f"🔍 First 5 log entries: {dict(list(log.items())[:5])}")

# ============================================================
# Final column cleanup & ordering
# ============================================================

# 1. Drop uniprot_id if exists
benchmark_df = benchmark_df.drop(columns=["uniprot_id", "protein_variant"], errors="ignore")

# 2. Reorder columns: put am_score after (#CHROM, POS, ID)
cols = list(benchmark_df.columns)

anchor_cols = ["#CHROM", "POS", "ID"]

# Check which anchor columns actually exist
anchor_present = [c for c in anchor_cols if c in cols]

if "am_score" in cols and anchor_present:
    # Remove am_score first
    cols.remove("am_score")

    # Find insertion position (after last anchor col)
    last_anchor_idx = max(cols.index(c) for c in anchor_present)

    # Insert am_score after that
    cols.insert(last_anchor_idx + 1, "am_score")

    benchmark_df = benchmark_df[cols]
else:
    print("⚠️ Could not reorder am_score (missing columns?)")

# ============================================================
# 9. Save
# ============================================================
print(f"final benchmark len = {len(benchmark_df)}")
benchmark_df.to_csv(output_am_score_path, index=False)
print("alphamissense_merge_stop_gain_combined.py done ✅")
# Out:
# 1 input query terms found no hit:	['NM_032374.4']
# ✅ Finished mapping: 10433 UniProt IDs found.
# Reading AlphaMissense: 100%|█████████████████████████████████████████████████████████| 144/144 [02:58<00:00,  1.24s/it]
# ✅ Collected variants for 10241 proteins.
# ✅ No inconsistent am_scores
# benchmark len before = 242132
# benchmark len after  = 242132
# Processing stop_gains: 100%|███████████████████████████████████████████████████| 42000/42000 [00:38<00:00, 1100.79it/s]
# ✅ Number of stop_gain am_scores updated: 41370
# 🔍 First 5 log entries: {'Q96L58': 'Y212AEGIKLMPQRTVWY', 'O14640': 'Y377AEGIKLMPQRTVWY', 'Q6PCB0': 'S183CDEFGHIKMNQRSVWY', 'Q9NVI7': 'R188ADEFIKMNQRTVWY', 'P62873': 'R19ACDEFHIKMNRSTVWY'}
# final benchmark len = 242132
# alphamissense_merge_stop_gain_combined.py done ✅
