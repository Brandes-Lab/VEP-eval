# %% [markdown]
# Ensure you have a benchmark, e.g. ./benchmark/ClinVarBenchmark_PB_202504.csv <br>
# Also check if the link below is still valid for precomputed AlphaMissense scores <br>
# https://zenodo.org/records/10813168/files/AlphaMissense_hg38.tsv.gz

# %%
import sys
# !{sys.executable} -m pip install mygene

# %%
from tqdm import tqdm
import requests
from pathlib import Path
import gzip
import shutil
import os

am_url = "https://zenodo.org/records/10813168/files/AlphaMissense_aa_substitutions.tsv.gz"
am_gz = "AlphaMissense_aa_substitutions.tsv.gz"
am_path = "AlphaMissense_aa_substitutions.tsv"

def download_resume(url, filename):
    temp_size = 0
    headers = {}

    if Path(filename).exists():
        temp_size = Path(filename).stat().st_size
        headers["Range"] = f"bytes={temp_size}-"

    with requests.get(url, stream=True, headers=headers) as r:
        total_size = int(r.headers.get("content-length", 0)) + temp_size

        mode = "ab" if temp_size > 0 else "wb"

        with open(filename, mode) as f, tqdm(
            total=total_size,
            initial=temp_size,
            unit="B",
            unit_scale=True,
            desc="Downloading"
        ) as bar:
            for chunk in r.iter_content(chunk_size=1024*1024):
                if chunk:
                    f.write(chunk)
                    bar.update(len(chunk))


if Path(am_path).exists():
    print("AlphaMissense_aa_substitutions.tsv exists, skip downloading")

else:
    print("Downloading AlphaMissense_aa_substitutions.tsv.gz ...")
    download_resume(am_url, am_gz)

    print("Unzipping...")
    with gzip.open(am_gz, "rb") as f_in, open(am_path, "wb") as f_out:
        shutil.copyfileobj(f_in, f_out)

    Path(am_gz).unlink()

print("✅ Done")

import pandas as pd
am_preview = pd.read_csv(
    am_path,
    sep="\t",
    skiprows=3,
    nrows=5
)

print(am_preview.head())
# Out:
# AlphaMissense_aa_substitutions.tsv exists, skip downloading
# ✅ Done
#    uniprot_id protein_variant  am_pathogenicity    am_class
# 0  A0A024R1R8             M1A            0.4673   ambiguous
# 1  A0A024R1R8             M1C            0.3828   ambiguous
# 2  A0A024R1R8             M1D            0.8267  pathogenic
# 3  A0A024R1R8             M1E            0.5236   ambiguous
# 4  A0A024R1R8             M1F            0.2753      benign

# %%
import re
import time
import math
import numpy as np
import pandas as pd
import mygene
from tqdm import tqdm

# ============================================================
# Config
# ============================================================
current_score_path = "all_scores_ClinVar.csv"
output_am_score_path = "all_scores_am.csv"
chunksize = 500_000

# ============================================================
# 1. Load benchmark
# ============================================================
benchmark_df = pd.read_csv(current_score_path, dtype={"#CHROM": str}).copy()
benchmark_df = benchmark_df.drop(columns=["am_score"], errors="ignore")

# ============================================================
# 2. Map RefSeq NM -> UniProt
# ============================================================
def map_nm_to_uniprot_batch(nm_ids):
    mg = mygene.MyGeneInfo()

    results = mg.querymany(
        nm_ids,
        scopes="refseq",
        fields="uniprot",
        species="human",
        as_dataframe=False,
        verbose=False
    )

    nm_to_uniprot = {}

    for res in results:
        refseq = res.get("query")
        uniprot = res.get("uniprot", {})
        uniprot_id = None

        if isinstance(uniprot, dict):
            ids = uniprot.get("Swiss-Prot") or uniprot.get("TrEMBL")
            uniprot_id = ids[0] if isinstance(ids, list) else ids
        elif isinstance(uniprot, list):
            uniprot_id = uniprot[0] if uniprot else None
        else:
            uniprot_id = uniprot

        nm_to_uniprot[refseq] = uniprot_id

    return nm_to_uniprot


if "uniprot_id" not in benchmark_df.columns:
    nm_ids = benchmark_df["ClinVarName_refseq_ids"].dropna().unique().tolist()

    batch_size = 200
    nm_to_uniprot = {}

    for i in tqdm(range(0, len(nm_ids), batch_size), desc="Mapping NM -> UniProt"):
        batch = nm_ids[i:i + batch_size]

        try:
            batch_map = map_nm_to_uniprot_batch(batch)
            nm_to_uniprot.update(batch_map)

        except Exception as e:
            print(f"❌ Batch {i}-{i+len(batch)} failed: {e}")
            time.sleep(3)

    benchmark_df["uniprot_id"] = benchmark_df["ClinVarName_refseq_ids"].map(nm_to_uniprot)

# ============================================================
# 3. Build protein_variant in benchmark
# ============================================================
benchmark_df["protein_variant"] = (
    benchmark_df["ClinVarName_AAREF"].astype(str)
    + benchmark_df["ClinVarName_AAPOS"].astype("Int64").astype(str)
    + benchmark_df["ClinVarName_AAALT"].astype(str)
)

needed_uniprots = set(benchmark_df["uniprot_id"].dropna())
print(f"Needed UniProt IDs: {len(needed_uniprots):,}")

# ============================================================
# 4. Helpers
# ============================================================
AA_VOCAB = [
    "K", "R", "H", "E", "D", "N", "Q", "T", "S", "C",
    "G", "A", "V", "L", "I", "M", "P", "Y", "F", "W"
]

def parse_mut(protein_variant):
    match = re.match(r"([A-Z])(\d+)([A-Z*])", str(protein_variant))
    if match:
        ref, pos, alt = match.groups()
        return ref, int(pos), alt
    return None, None, None

def report_group_coverage(df, score_col="am_score"):
    group_cols = [c for c in df.columns if c.startswith("group:")]

    if not group_cols:
        print("⚠️ No group columns found.")
        return pd.DataFrame(columns=["group", "filled", "total", "missing"])

    rows = []

    for col in group_cols:
        subset = df[df[col] == 1]

        total = len(subset)
        filled = subset[score_col].notna().sum()

        rows.append({
            "group": col,
            "filled": filled,
            "total": total,
            "missing": total - filled
        })

    summary = pd.DataFrame(rows)

    return summary

# ============================================================
# 5. Read AlphaMissense AA substitutions
# ============================================================
am_parts = []
protein_variants = {}

print("Reading AlphaMissense AA substitutions...")

with open(am_path) as f:
    total_lines = sum(1 for _ in f)

data_lines = max(total_lines - 3, 0)
n_chunks = math.ceil(data_lines / chunksize)

for chunk in tqdm(
    pd.read_csv(am_path, sep="\t", skiprows=3, chunksize=chunksize),
    total=n_chunks,
    desc="Reading AlphaMissense AA"
):
    chunk = chunk.rename(columns={"am_pathogenicity": "am_score"})

    required = ["uniprot_id", "protein_variant", "am_score"]
    missing = [c for c in required if c not in chunk.columns]
    if missing:
        raise ValueError(f"Missing columns in AlphaMissense AA file: {missing}")

    chunk = chunk[chunk["uniprot_id"].isin(needed_uniprots)].copy()
    if chunk.empty:
        continue

    # direct merge table
    am_parts.append(chunk[["uniprot_id", "protein_variant", "am_score"]].copy())

    # stop_gain support table
    parsed = chunk["protein_variant"].apply(parse_mut)
    chunk[["ref", "pos", "alt"]] = pd.DataFrame(parsed.tolist(), index=chunk.index)

    stop_df = chunk[
        ["uniprot_id", "ref", "pos", "alt", "am_score"]
    ].dropna(subset=["pos"]).copy()

    stop_df["pos"] = stop_df["pos"].astype(int)

    for uni, subdf in stop_df.groupby("uniprot_id"):
        if uni not in protein_variants:
            protein_variants[uni] = subdf.copy()
        else:
            protein_variants[uni] = pd.concat(
                [protein_variants[uni], subdf],
                ignore_index=True
            )

print(f"Collected proteins for stop_gain: {len(protein_variants):,}")

if am_parts:
    am_var = pd.concat(am_parts, ignore_index=True)
else:
    am_var = pd.DataFrame(columns=["uniprot_id", "protein_variant", "am_score"])

# ============================================================
# 6. Deduplicate protein-level AlphaMissense
# ============================================================
merge_cols = ["uniprot_id", "protein_variant"]

am_var = am_var.drop_duplicates()

dupes = am_var[am_var.duplicated(subset=merge_cols, keep=False)]

if not dupes.empty:
    bad_keys = (
        dupes.groupby(merge_cols, group_keys=False)
        .filter(lambda g: g["am_score"].nunique(dropna=False) > 1)[merge_cols]
        .drop_duplicates()
    )
else:
    bad_keys = pd.DataFrame(columns=merge_cols)

if not bad_keys.empty:
    print(f"❌ Found {len(bad_keys):,} inconsistent AM protein keys. Setting am_score=NaN")

    bad_key_set = set(map(tuple, bad_keys[merge_cols].to_numpy()))
    row_keys = list(map(tuple, am_var[merge_cols].to_numpy()))
    mask = pd.Series(row_keys).isin(bad_key_set).to_numpy()

    am_var.loc[mask, "am_score"] = np.nan
else:
    print("✅ No inconsistent AM protein keys")

am_var = am_var.drop_duplicates(subset=merge_cols, keep="first")

print(f"AM protein merge rows: {len(am_var):,}")

# ============================================================
# 7. Direct merge by UniProt + protein_variant
# ============================================================
before_len = len(benchmark_df)

benchmark_df = benchmark_df.merge(
    am_var,
    on=["uniprot_id", "protein_variant"],
    how="left"
)

after_len = len(benchmark_df)

print(f"benchmark len before = {before_len:,}")
print(f"benchmark len after  = {after_len:,}")

# ============================================================
# 8. Deduplicate stop_gain support dictionary
# ============================================================
invalidated_subkeys = {}

for uni in list(protein_variants.keys()):
    df = protein_variants[uni].drop_duplicates().copy()

    sub_cols = ["ref", "pos", "alt"]
    dupes2 = df[df.duplicated(subset=sub_cols, keep=False)]

    if not dupes2.empty:
        bad_subkeys = (
            dupes2.groupby(sub_cols, group_keys=False)
            .filter(lambda g: g["am_score"].nunique(dropna=False) > 1)[sub_cols]
            .drop_duplicates()
        )
    else:
        bad_subkeys = pd.DataFrame(columns=sub_cols)

    if not bad_subkeys.empty:
        bad_subkey_set = set(map(tuple, bad_subkeys[sub_cols].to_numpy()))
        sub_row_keys = list(map(tuple, df[sub_cols].to_numpy()))
        mask2 = pd.Series(sub_row_keys).isin(bad_subkey_set).to_numpy()
        print("⚠️ Duplicate exist in stop_gain.")

        df.loc[mask2, "am_score"] = np.nan
        invalidated_subkeys[uni] = set(map(tuple, bad_subkeys[sub_cols].to_numpy()))

    df = df.drop_duplicates(subset=sub_cols, keep="first")
    protein_variants[uni] = df

# ============================================================
# 9. Fill stop_gain AlphaMissense scores
# ============================================================
stop_mask = benchmark_df["ClinVarName_AAALT"].astype(str) == "*"
stop_indices = benchmark_df.index[stop_mask]

counter = 0
lost_stop = 0
log = {}

for idx in tqdm(stop_indices, desc="Processing stop_gains"):
    row = benchmark_df.loc[idx]

    uni = row["uniprot_id"]
    stop_pos = row["ClinVarName_AAPOS"]

    if pd.isna(uni) or pd.isna(stop_pos):
        continue

    stop_pos = int(stop_pos)

    if uni not in protein_variants:
        continue

    bad = invalidated_subkeys.get(uni, set())
    if any(pos >= stop_pos for (_, pos, _) in bad):
        lost_stop += 1

    pv = protein_variants[uni]
    after = pv[pv["pos"] >= stop_pos]

    if after.empty:
        continue

    # optional coverage check
    for p in sorted(after["pos"].dropna().unique()):
        subdf = after.loc[after["pos"] == p]
        missing_aas = set(AA_VOCAB) - set(subdf["alt"].dropna())

        if missing_aas:
            wt_ref = subdf["ref"].iloc[0] if not subdf.empty else "?"
            log[uni] = f"{wt_ref}{p}{''.join(sorted(missing_aas))}"
            break

    # AlphaMissense: higher = more pathogenic
    worst_score = after["am_score"].max()

    if pd.notna(worst_score):
        benchmark_df.at[idx, "am_score"] = worst_score
        counter += 1

print("Stop-gain benchmark rows affected by invalidated subkeys:", lost_stop)
print(f"✅ Number of stop_gain am_scores updated: {counter:,}")

# ============================================================
# 10. Final coverage report
# ============================================================
coverage_summary = report_group_coverage(
    benchmark_df,
    score_col="am_score"
)

print(coverage_summary)

coverage_summary.to_csv(
    "am_coverage_by_group_after_stop_gain.csv",
    index=False
)

# ============================================================
# 11. Cleanup and save
# ============================================================
benchmark_df = benchmark_df.drop(
    columns=["uniprot_id", "protein_variant"],
    errors="ignore"
)

print(f"final benchmark len = {len(benchmark_df):,}")

benchmark_df.to_csv(output_am_score_path, index=False)

print("AlphaMissense AA-substitution merge + stop_gain done ✅")
# Out:
# Mapping NM -> UniProt: 100%|███████████████████████████████████████████████████████████| 57/57 [01:39<00:00,  1.75s/it]
# Rows with UniProt: 239,216
# Needed UniProt IDs: 10,433
# Reading AlphaMissense AA substitutions...
# Reading AlphaMissense AA: 100%|██████████████████████████████████████████████████████| 433/433 [05:55<00:00,  1.22it/s]
# Collected proteins for stop_gain: 10,392
# ✅ No inconsistent AM protein keys
# AM protein merge rows: 142,324,630
# benchmark len before = 242,132
# benchmark len after  = 242,132
# Processing stop_gains: 100%|████████████████████████████████████████████████████| 42000/42000 [01:07<00:00, 619.25it/s]
# Stop-gain benchmark rows affected by invalidated subkeys: 0
# ✅ Number of stop_gain am_scores updated: 41,803
#
# ===== Final coverage by group AFTER stop_gain fill =====
# group: coding; 82509/125931 missing=43422
# group: noncoding; 0/116201 missing=116201
# group: start loss; 788/791 missing=3
# group: start loss + 3'UTR; 2/2 missing=0
# ...
