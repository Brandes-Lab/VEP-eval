# %% [markdown]
# # Map precomputed GPN-MSA scores
#
# **Purpose.** Map the official precomputed GPN-MSA table to benchmark variants.
#
# ## Reproducibility contract
#
# - **Run from:** the repository root or this notebook's model directory.
# - **Genome build:** GRCh38/hg38.
# - **Variant key:** `#CHROM`, `POS`, `REF`, and `ALT`.
# - **Input:** `data/sample_data.csv.gz`.
# - **Output:** `data/model_scores/gpn_msa.csv.gz`.
# - **Source:** https://huggingface.co/datasets/songlab/gpn-msa-hg38-scores
# - **Prepare input:** Download [scores](https://huggingface.co/datasets/songlab/gpn-msa-hg38-scores/resolve/main/scores.tsv.bgz) as `data/raw/gpn_msa_scores.tsv.bgz` and its [tabix index](https://huggingface.co/datasets/songlab/gpn-msa-hg38-scores/resolve/main/scores.tsv.bgz.tbi) as `data/raw/gpn_msa_scores.tsv.bgz.tbi`.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path

# Support kernels started from either the repository root or this notebook's directory.
START_DIR = Path.cwd().resolve()
REPO_ROOT = START_DIR if (START_DIR / "data" / "sample_data.csv.gz").is_file() else START_DIR.parent
DATA_DIR = REPO_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
MODEL_SCORE_DIR = DATA_DIR / "model_scores"
BENCHMARK_PATH = DATA_DIR / "sample_data.csv.gz"
VARIANT_KEY = ["#CHROM", "POS", "REF", "ALT"]

OUTPUT_PATH = MODEL_SCORE_DIR / "gpn_msa.csv.gz"
MODEL_SCORE_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Install dependencies and load inputs

# %% [markdown]
# ## 3. Run scoring or score mapping

# %%
# %pip install pysam tqdm

# %% [markdown]
# ## 4. Validate and save output

# %%
import pandas as pd
import pysam
from tqdm import tqdm

# Configure file paths
input_csv = BENCHMARK_PATH
bgz_file = RAW_DATA_DIR / "gpn_msa_scores.tsv.bgz"
output_csv = OUTPUT_PATH

# Load variant data
df = pd.read_csv(input_csv)
df["#CHROM"] = df["#CHROM"].astype(str)
df["POS"] = df["POS"].astype(int)

# Open tabix-indexed file
tbx = pysam.TabixFile(str(bgz_file))

# Prepare result list
gpn_scores = []

# Query GPN-MSA score for each variant
for _, row in tqdm(df.iterrows(), total=len(df), desc="Querying GPN-MSA"):
    chrom = row["#CHROM"]
    pos = row["POS"]
    ref = row["REF"]
    alt = row["ALT"]

    region = f"{chrom}:{pos}-{pos}"
    found = False
    score = None
    try:
        for record in tbx.fetch(region=region):
            fields = record.strip().split("\t")
            if len(fields) < 5:
                continue
            r_ref, r_alt, r_score = fields[2], fields[3], fields[4]
            if r_ref == ref and r_alt == alt:
                score = float(r_score)
                found = True
                break
    except Exception:
        pass

    gpn_scores.append(score)

# Add scores to DataFrame and save
df["GPN_MSA"] = gpn_scores
df[VARIANT_KEY + ["GPN_MSA"]].to_csv(
    output_csv, index=False, compression="gzip"
)
print(f"Done! GPN-MSA scores saved to {output_csv}")
